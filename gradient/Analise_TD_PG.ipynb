# %% [markdown]
# # Experimentos de Aprendizado por Reforço em Cliff World 10x10
#
# Este notebook apresenta uma comparação completa entre algoritmos clássicos de RL (baseados em valor) e algoritmos de gradiente de política, aplicados a um ambiente Cliff World 10x10 com características desafiadoras.
#
# ---
#
# ## 📚 Sumário
#
# 1. [Configuração do Ambiente](#1-configuração-do-ambiente)
# 2. [SARSA - State-Action-Reward-State-Action](#2-sarsa)
# 3. [Q-Learning](#3-q-learning)
# 4. [Expected SARSA](#4-expected-sarsa)
# 5. [REINFORCE - Monte Carlo Policy Gradient](#5-reinforce)
# 6. [REINFORCE com Baseline](#6-reinforce-com-baseline)
# 7. [Actor-Critic (One-Step)](#7-actor-critic)
# 8. [Comparação Final](#8-comparação-final)
#
# ---

# %%
## 1. Configuração do Ambiente

### 1.1 Imports Necessários


import numpy as np
import matplotlib.pyplot as plt
from environment import create_custom_gridworld, print_gridworld_info
from algorithms import sarsa, q_learning, expected_sarsa, get_greedy_policy
from algorithms_extended import reinforce, reinforce_baseline, actor_critic
from visualization import (visualize_gridworld, visualize_q_values, 
                           plot_learning_curves, compare_algorithms)
from visualization_extended import (visualize_stochastic_policy, plot_policy_arrows,
                                   plot_policy_gradient_learning, plot_value_and_policy)

# Configurações para reprodutibilidade
np.random.seed(42)

#plt.style.use('seaborn-v0_8-darkgrid')

# %% [markdown]
# ### 1.2 Criação do Cliff World 10x10
#
# **Descrição do Ambiente:**
#
# O Cliff World é um ambiente clássico de RL que testa a capacidade dos algoritmos de encontrar caminhos seguros versus caminhos ótimos. Nosso ambiente 10x10 possui:
#
# - **Estado inicial (S)**: Canto inferior esquerdo `(9, 0)`
# - **Estado objetivo (G)**: Canto inferior direito `(9, 9)`
# - **Abismos (C)**: Toda a linha inferior entre S e G `(9, 1)` até `(9, 8)`
# - **Recompensas**:
#   - Cair no abismo: **-100**
#   - Alcançar objetivo: **+10**
#   - Cada passo: **-1** (incentiva caminhos curtos)
#
# **Layout:**
# ```
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [S][C][C][C][C][C][C][C][C][G]
# ```

# %%
# Cria ambiente Cliff World 10x10
gw = create_custom_gridworld(
    rows=6,
    cols=10,
    walls=[
        (3,1),(2,2),
        (3,3),(2,4),
        (3,5),(2,6),
        (3,7),(2,8),
          ],  # Sem paredes internas
    terminals={
        # Abismos na última linha (exceto cantos)
        **{(5, col): -10.0 for col in range(1, 9)},
        # Abismos na primeira linha (exceto cantos)
        **{(0, col): -50.0 for col in range(1, 9)},
        # Objetivo no canto inferior direito
        (5, 9): 10.0,
        (0, 9): 10.0
    },
    gamma=0.99,
    noise=0.0,  # Determinístico
    living_reward=-1.0
)

# Exibe informações
print_gridworld_info(gw)
# Out:
# ======================================================================
# INFORMAÇÕES DO GRIDWORLD
# ======================================================================
# Dimensões: 6 linhas x 10 colunas
# Total de estados: 52
# Paredes: 8
# Estados terminais: 18
# Fator de desconto (γ): 0.99
# Ruído: 0.0
# Living reward: -1.0
# Ações disponíveis: ['N', 'S', 'L', 'O']
#
# Paredes: [(2, 2), (2, 4), (2, 6), (2, 8), (3, 1), (3, 3), (3, 5), (3, 7)]
#
# Estados terminais:
#   (0, 1): reward = -50.0
#   (0, 2): reward = -50.0
#   (0, 3): reward = -50.0
#   (0, 4): reward = -50.0
#   (0, 5): reward = -50.0
#   (0, 6): reward = -50.0
#   (0, 7): reward = -50.0
#   (0, 8): reward = -50.0
#   (0, 9): reward = 10.0
#   (5, 1): reward = -10.0
#   (5, 2): reward = -10.0
#   (5, 3): reward = -10.0
#   (5, 4): reward = -10.0
#   (5, 5): reward = -10.0
#   (5, 6): reward = -10.0
#   (5, 7): reward = -10.0
#   (5, 8): reward = -10.0
#   (5, 9): reward = 10.0
# ======================================================================

# %%
### 1.3 Visualização do Ambiente


# Visualiza o ambiente
visualize_gridworld(
    gw,
    title="Cliff World 6x10 - Ambiente",
    figsize=(10, 10)
)

# %% [markdown]
# **Ponto de partida típico para treinamento:**
#
# ```python
# # Define estado inicial fixo para todos os experimentos
# INITIAL_STATE = (9, 0)  # Canto inferior esquerdo
#
# print(f"Estado inicial: {INITIAL_STATE}")
# print(f"Estado objetivo: (9, 9)")
# print(f"Número de abismos: {len([s for s in gw.terminal_states if gw.terminal_states[s] < 0])}")
# ```

# %%
# Define estado inicial fixo para todos os experimentos
INITIAL_STATE = (5, 0)  # Canto inferior esquerdo

print(f"Estado inicial: {INITIAL_STATE}")
print(f"Estados objetivos: (5, 9)")
print(f"Número de abismos: {len([s for s in gw.terminal_states if gw.terminal_states[s] < 0])}")
# Out:
# Estado inicial: (5, 0)
# Estados objetivos: (5, 9)
# Número de abismos: 16

# %% [markdown]
# ## 2. SARSA - State-Action-Reward-State-Action
#
# ### 2.1 Intuição
#
# **SARSA** é um algoritmo **on-policy** de Temporal Difference (TD). Ele aprende o valor $Q(s,a)$ da política que está **atualmente seguindo** (incluindo a exploração $\epsilon$-greedy).
#
# **Características:**
# - ✅ Conservador: aprende políticas mais seguras
# - ✅ Considera a exploração durante o aprendizado
# - ❌ Pode ser mais lento para convergir
# - 📊 Ideal quando a exploração tem custos reais
#
# ### 2.2 Pseudocódigo
#
# ```
# Inicializar Q(s,a) arbitrariamente
# Para cada episódio:
#     S ← estado inicial
#     A ← ação escolhida por ε-greedy usando Q
#
#     Repetir para cada passo do episódio:
#         Executar ação A, observar R, S'
#         A' ← ação escolhida por ε-greedy usando Q (do próximo estado)
#
#         Q(S,A) ← Q(S,A) + α[R + γQ(S',A') - Q(S,A)]
#
#         S ← S'
#         A ← A'
#     até S ser terminal
# ```
#
# ### 2.3 Equação de Atualização
#
# $$Q(S_t, A_t) \leftarrow Q(S_t, A_t) + \alpha \left[ R_{t+1} + \gamma Q(S_{t+1}, A_{t+1}) - Q(S_t, A_t) \right]$$
#
# **Nota importante:** O algoritmo usa $Q(S_{t+1}, A_{t+1})$ onde $A_{t+1}$ é escolhida pela política atual (ε-greedy), não pela política gulosa.

# %%
### 2.4 Treinamento do SARSA

print("="*80)
print("TREINANDO SARSA")
print("="*80)

# Hiperparâmetros
N_EPISODES = 3000
ALPHA = 0.1      # Taxa de aprendizado
EPSILON = 0.1    # Exploração
GAMMA = 0.99     # Desconto (já definido no ambiente)

# Treina SARSA
Q_sarsa, rewards_sarsa = sarsa(
    gw,
    n_episodes=N_EPISODES,
    alpha=ALPHA,
    epsilon=EPSILON,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_sarsa[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO SARSA
# ================================================================================
# Episódio 100/3000 - Reward médio: -51.73
# Episódio 200/3000 - Reward médio: -14.41
# Episódio 300/3000 - Reward médio: -3.03
# Episódio 400/3000 - Reward médio: -4.10
# Episódio 500/3000 - Reward médio: -5.11
# Episódio 600/3000 - Reward médio: -3.61
# Episódio 700/3000 - Reward médio: -4.27
# Episódio 800/3000 - Reward médio: -4.62
# Episódio 900/3000 - Reward médio: -4.29
# Episódio 1000/3000 - Reward médio: -4.38
# Episódio 1100/3000 - Reward médio: -4.52
# Episódio 1200/3000 - Reward médio: -4.51
# Episódio 1300/3000 - Reward médio: -3.45
# Episódio 1400/3000 - Reward médio: -4.73
# Episódio 1500/3000 - Reward médio: -3.98
# Episódio 1600/3000 - Reward médio: -4.28
# Episódio 1700/3000 - Reward médio: -3.86
# Episódio 1800/3000 - Reward médio: -9.43
# Episódio 1900/3000 - Reward médio: -4.64
# Episódio 2000/3000 - Reward médio: -5.38
# Episódio 2100/3000 - Reward médio: -4.87
# Episódio 2200/3000 - Reward médio: -4.56
# Episódio 2300/3000 - Reward médio: -4.70
# Episódio 2400/3000 - Reward médio: -5.04
# Episódio 2500/3000 - Reward médio: -3.99
# Episódio 2600/3000 - Reward médio: -4.86
# Episódio 2700/3000 - Reward médio: -4.66
# Episódio 2800/3000 - Reward médio: -4.98
# Episódio 2900/3000 - Reward médio: -4.16
# Episódio 3000/3000 - Reward médio: -4.32
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -4.32

# %%
### 2.5 Visualização dos Resultados - SARSA

#### Curva de Aprendizado


plot_learning_curves(
    {'SARSA': rewards_sarsa},
    title="SARSA - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Aprendida


# Extrai política gulosa
policy_sarsa = get_greedy_policy(Q_sarsa, gw)

# Visualiza política
visualize_gridworld(
    gw,
    policy=policy_sarsa,
    title="SARSA - Política Aprendida",
    figsize=(12, 12)
)

# %%
#### Valores Q Aprendidos


# Visualiza valores máximos por estado
visualize_q_values(
    Q_sarsa,
    gw,
    title="SARSA - Valores Q Máximos por Estado",
    figsize=(12, 12)
)

# %% [markdown]
# ## 3. Q-Learning
#
# ### 3.1 Intuição
#
# **Q-Learning** é um algoritmo **off-policy** de TD. Ele aprende o valor $Q(s,a)$ da política **ótima** (gulosa), independentemente da política que está seguindo para exploração.
#
# **Características:**
# - ✅ Aprende a política ótima diretamente
# - ✅ Converge mais rápido
# - ⚠️ Mais agressivo: pode encontrar caminhos arriscados
# - 📊 Ideal quando podemos explorar livremente
#
# ### 3.2 Pseudocódigo
#
# ```
# Inicializar Q(s,a) arbitrariamente
# Para cada episódio:
#     S ← estado inicial
#
#     Repetir para cada passo do episódio:
#         A ← ação escolhida por ε-greedy usando Q
#         Executar ação A, observar R, S'
#
#         Q(S,A) ← Q(S,A) + α[R + γ max_a' Q(S',a') - Q(S,A)]
#
#         S ← S'
#     até S ser terminal
# ```
#
# ### 3.3 Equação de Atualização
#
# $$Q(S_t, A_t) \leftarrow Q(S_t, A_t) + \alpha \left[ R_{t+1} + \gamma \max_{a} Q(S_{t+1}, a) - Q(S_t, A_t) \right]$$
#
# **Diferença chave:** Usa $\max_a Q(S_{t+1}, a)$ (política gulosa) ao invés de $Q(S_{t+1}, A_{t+1})$ (política atual).

# %%
### 3.4 Treinamento do Q-Learning


print("="*80)
print("TREINANDO Q-LEARNING")
print("="*80)

# Treina Q-Learning (mesmos hiperparâmetros)
Q_qlearning, rewards_qlearning = q_learning(
    gw,
    n_episodes=N_EPISODES,
    alpha=ALPHA,
    epsilon=EPSILON,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_qlearning[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO Q-LEARNING
# ================================================================================
# Episódio 100/3000 - Reward médio: -44.99
# Episódio 200/3000 - Reward médio: -12.69
# Episódio 300/3000 - Reward médio: -4.23
# Episódio 400/3000 - Reward médio: -4.63
# Episódio 500/3000 - Reward médio: -4.24
# Episódio 600/3000 - Reward médio: -4.82
# Episódio 700/3000 - Reward médio: -3.69
# Episódio 800/3000 - Reward médio: -3.65
# Episódio 900/3000 - Reward médio: -5.14
# Episódio 1000/3000 - Reward médio: -3.80
# Episódio 1100/3000 - Reward médio: -4.25
# Episódio 1200/3000 - Reward médio: -3.58
# Episódio 1300/3000 - Reward médio: -4.92
# Episódio 1400/3000 - Reward médio: -4.31
# Episódio 1500/3000 - Reward médio: -4.24
# Episódio 1600/3000 - Reward médio: -2.76
# Episódio 1700/3000 - Reward médio: -3.71
# Episódio 1800/3000 - Reward médio: -4.05
# Episódio 1900/3000 - Reward médio: -4.18
# Episódio 2000/3000 - Reward médio: -3.45
# Episódio 2100/3000 - Reward médio: -4.11
# Episódio 2200/3000 - Reward médio: -3.90
# Episódio 2300/3000 - Reward médio: -3.83
# Episódio 2400/3000 - Reward médio: -4.10
# Episódio 2500/3000 - Reward médio: -3.80
# Episódio 2600/3000 - Reward médio: -4.48
# Episódio 2700/3000 - Reward médio: -4.85
# Episódio 2800/3000 - Reward médio: -3.45
# Episódio 2900/3000 - Reward médio: -3.79
# Episódio 3000/3000 - Reward médio: -4.33
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -4.33

# %%
### 3.5 Visualização dos Resultados - Q-Learning

#### Curva de Aprendizado


plot_learning_curves(
    {'Q-Learning': rewards_qlearning},
    title="Q-Learning - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Aprendida


# Extrai política gulosa
policy_qlearning = get_greedy_policy(Q_qlearning, gw)

# Visualiza política
visualize_gridworld(
    gw,
    policy=policy_qlearning,
    title="Q-Learning - Política Aprendida",
    figsize=(12, 12)
)

# %%
#### Valores Q Aprendidos


# Visualiza valores máximos por estado
visualize_q_values(
    Q_qlearning,
    gw,
    title="Q-Learning - Valores Q Máximos por Estado",
    figsize=(12, 12)
)

# %% [markdown]
# ## 4. Expected SARSA
#
# ### 4.1 Intuição
#
# **Expected SARSA** é uma variação do SARSA que usa o **valor esperado** das ações no próximo estado ao invés de uma ação específica. Isso reduz a variância das atualizações.
#
# **Características:**
# - ✅ Menos variância que SARSA
# - ✅ Mais estável que Q-Learning
# - ✅ Pode ser on-policy ou off-policy
# - 📊 Bom compromisso entre SARSA e Q-Learning
#
# ### 4.2 Pseudocódigo
#
# ```
# Inicializar Q(s,a) arbitrariamente
# Para cada episódio:
#     S ← estado inicial
#
#     Repetir para cada passo do episódio:
#         A ← ação escolhida por ε-greedy usando Q
#         Executar ação A, observar R, S'
#
#         expected_Q ← Σ_a' π(a'|S') Q(S',a')
#         Q(S,A) ← Q(S,A) + α[R + γ expected_Q - Q(S,A)]
#
#         S ← S'
#     até S ser terminal
# ```
#
# ### 4.3 Equação de Atualização
#
# $$Q(S_t, A_t) \leftarrow Q(S_t, A_t) + \alpha \left[ R_{t+1} + \gamma \mathbb{E}_\pi[Q(S_{t+1}, \cdot)] - Q(S_t, A_t) \right]$$
#
# onde:
#
# $$\mathbb{E}_\pi[Q(S_{t+1}, \cdot)] = \sum_{a} \pi(a|S_{t+1}) Q(S_{t+1}, a)$$
#
# Para política $\epsilon$-greedy:
#
# $$\mathbb{E}_\pi[Q(s, \cdot)] = (1-\epsilon) \max_a Q(s,a) + \epsilon \cdot \frac{1}{|A|} \sum_a Q(s,a)$$

# %%
### 4.4 Treinamento do Expected SARSA


print("="*80)
print("TREINANDO EXPECTED SARSA")
print("="*80)

# Treina Expected SARSA
Q_expected, rewards_expected = expected_sarsa(
    gw,
    n_episodes=N_EPISODES,
    alpha=ALPHA,
    epsilon=EPSILON,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_expected[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO EXPECTED SARSA
# ================================================================================
# Episódio 100/3000 - Reward médio: -46.55
# Episódio 200/3000 - Reward médio: -12.09
# Episódio 300/3000 - Reward médio: -5.64
# Episódio 400/3000 - Reward médio: -3.98
# Episódio 500/3000 - Reward médio: -3.95
# Episódio 600/3000 - Reward médio: -4.05
# Episódio 700/3000 - Reward médio: -4.06
# Episódio 800/3000 - Reward médio: -4.92
# Episódio 900/3000 - Reward médio: -4.99
# Episódio 1000/3000 - Reward médio: -3.56
# Episódio 1100/3000 - Reward médio: -4.37
# Episódio 1200/3000 - Reward médio: -4.33
# Episódio 1300/3000 - Reward médio: -5.12
# Episódio 1400/3000 - Reward médio: -5.49
# Episódio 1500/3000 - Reward médio: -3.54
# Episódio 1600/3000 - Reward médio: -3.88
# Episódio 1700/3000 - Reward médio: -2.96
# Episódio 1800/3000 - Reward médio: -3.48
# Episódio 1900/3000 - Reward médio: -3.53
# Episódio 2000/3000 - Reward médio: -3.31
# Episódio 2100/3000 - Reward médio: -5.23
# Episódio 2200/3000 - Reward médio: -3.69
# Episódio 2300/3000 - Reward médio: -3.89
# Episódio 2400/3000 - Reward médio: -3.59
# Episódio 2500/3000 - Reward médio: -4.08
# Episódio 2600/3000 - Reward médio: -4.85
# Episódio 2700/3000 - Reward médio: -3.95
# Episódio 2800/3000 - Reward médio: -4.04
# Episódio 2900/3000 - Reward médio: -4.58
# Episódio 3000/3000 - Reward médio: -4.46
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -4.46

# %%
### 4.5 Visualização dos Resultados - Expected SARSA

#### Curva de Aprendizado


plot_learning_curves(
    {'Expected SARSA': rewards_expected},
    title="Expected SARSA - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Aprendida


# Extrai política gulosa
policy_expected = get_greedy_policy(Q_expected, gw)

# Visualiza política
visualize_gridworld(
    gw,
    policy=policy_expected,
    title="Expected SARSA - Política Aprendida",
    figsize=(12, 12)
)

# %%
#### Valores Q Aprendidos


# Visualiza valores máximos por estado
visualize_q_values(
    Q_expected,
    gw,
    title="Expected SARSA - Valores Q Máximos por Estado",
    figsize=(12, 12)
)

# %% [markdown]
# ---
#
# ## 5. REINFORCE - Monte Carlo Policy Gradient
#
# ### 5.1 Intuição
#
# **REINFORCE** é um algoritmo de **gradiente de política** que parametriza diretamente a política $\pi(a|s, \theta)$ e otimiza os parâmetros $\theta$ para maximizar a recompensa esperada.
#
# **Diferenças fundamentais:**
# - ❌ Não aprende valores Q(s,a)
# - ✅ Aprende política estocástica diretamente
# - ✅ Funciona bem em espaços contínuos
# - ⚠️ Alta variância (usa retornos completos)
#
# **Representação da Política:**
# Usamos política **softmax** (Boltzmann):
#
# $$\pi(a|s, \theta) = \frac{e^{h(s,a,\theta)}}{\sum_{b} e^{h(s,b,\theta)}}$$
#
# onde $h(s,a,\theta) = \theta^T \phi(s,a)$ são as "preferências" e $\phi(s,a)$ são features (one-hot encoding no nosso caso).
#
# ### 5.2 Pseudocódigo
#
# ```
# Inicializar θ (parâmetros da política) arbitrariamente
#
# Para cada episódio:
#     Gerar episódio S₀, A₀, R₁, ..., Sₜ, Aₜ, Rₜ₊₁ seguindo π(·|·,θ)
#
#     Para cada passo t do episódio:
#         Gₜ ← Σₖ₌₀^∞ γᵏ Rₜ₊ₖ₊₁   # Retorno descontado
#
#         θ ← θ + α γᵗ Gₜ ∇log π(Aₜ|Sₜ,θ)
# ```
#
# ### 5.3 Equação de Atualização
#
# **Gradiente do objetivo:**
#
# $$\nabla J(\theta) = \mathbb{E}_\pi \left[ G_t \nabla \log \pi(A_t|S_t, \theta) \right]$$
#
# **Atualização de parâmetros:**
#
# $$\theta \leftarrow \theta + \alpha \gamma^t G_t \nabla \log \pi(A_t|S_t, \theta)$$
#
# **Gradiente para política softmax:**
#
# $$\nabla \log \pi(a|s, \theta) = \phi(s,a) - \sum_{b} \pi(b|s,\theta) \phi(s,b)$$

# %%
### 5.4 Treinamento do REINFORCE


print("="*80)
print("TREINANDO REINFORCE")
print("="*80)

# Hiperparâmetros para REINFORCE
N_EPISODES_PG =50000  # Algoritmos PG geralmente precisam de mais episódios
ALPHA_THETA = 2**-9   # Taxa de aprendizado para parâmetros da política (~0.002)
GAMMA_PG = 0.99

# Treina REINFORCE
theta_reinforce, rewards_reinforce = reinforce(
    gw,
    n_episodes=N_EPISODES_PG,
    alpha_theta=ALPHA_THETA,
    gamma=GAMMA_PG,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_reinforce[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO REINFORCE
# ================================================================================
# EpisÃ³dio 100/50000 - Reward mÃ©dio: -15.41
# EpisÃ³dio 200/50000 - Reward mÃ©dio: -12.55
# EpisÃ³dio 300/50000 - Reward mÃ©dio: -11.31
# EpisÃ³dio 400/50000 - Reward mÃ©dio: -11.87
# EpisÃ³dio 500/50000 - Reward mÃ©dio: -11.22
# EpisÃ³dio 600/50000 - Reward mÃ©dio: -10.68
# EpisÃ³dio 700/50000 - Reward mÃ©dio: -10.28
# EpisÃ³dio 800/50000 - Reward mÃ©dio: -10.30
# EpisÃ³dio 900/50000 - Reward mÃ©dio: -10.39
# EpisÃ³dio 1000/50000 - Reward mÃ©dio: -10.14
# EpisÃ³dio 1100/50000 - Reward mÃ©dio: -10.42
# EpisÃ³dio 1200/50000 - Reward mÃ©dio: -10.18
# EpisÃ³dio 1300/50000 - Reward mÃ©dio: -10.19
# EpisÃ³dio 1400/50000 - Reward mÃ©dio: -10.19
# EpisÃ³dio 1500/50000 - Reward mÃ©dio: -10.28
# EpisÃ³dio 1600/50000 - Reward mÃ©dio: -10.12
# EpisÃ³dio 1700/50000 - Reward mÃ©dio: -10.10
# EpisÃ³dio 1800/50000 - Reward mÃ©dio: -10.11
# EpisÃ³dio 1900/50000 - Reward mÃ©dio: -10.14
# EpisÃ³dio 2000/50000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 2100/50000 - Reward mÃ©dio: -10.13
# EpisÃ³dio 2200/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 2300/50000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 2400/50000 - Reward mÃ©dio: -10.14
# EpisÃ³dio 2500/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 2600/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 2700/50000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 2800/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 2900/50000 - Reward mÃ©dio: -10.08
# EpisÃ³dio 3000/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 3100/50000 - Reward mÃ©dio: -10.12
# EpisÃ³dio 3200/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 3300/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 3400/50000 - Reward mÃ©dio: -10.12
# EpisÃ³dio 3500/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 3600/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 3700/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 3800/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 3900/50000 - Reward mÃ©dio: -10.20
# EpisÃ³dio 4000/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 4100/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 4200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 4300/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 4400/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 4500/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 4600/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 4700/50000 - Reward mÃ©dio: -10.16
# EpisÃ³dio 4800/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 4900/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 5000/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 5100/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 5200/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 5300/50000 - Reward mÃ©dio: -10.50
# EpisÃ³dio 5400/50000 - Reward mÃ©dio: -10.08
# EpisÃ³dio 5500/50000 - Reward mÃ©dio: -10.08
# EpisÃ³dio 5600/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 5700/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 5800/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 5900/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 6000/50000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 6100/50000 - Reward mÃ©dio: -10.10
# EpisÃ³dio 6200/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 6300/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 6400/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 6500/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 6600/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 6700/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 6800/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 6900/50000 - Reward mÃ©dio: -10.08
# EpisÃ³dio 7000/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 7100/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 7200/50000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 7300/50000 - Reward mÃ©dio: -10.15
# EpisÃ³dio 7400/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 7500/50000 - Reward mÃ©dio: -10.11
# EpisÃ³dio 7600/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 7700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 7800/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 7900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 8000/50000 - Reward mÃ©dio: -10.11
# EpisÃ³dio 8100/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 8200/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 8300/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 8400/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 8500/50000 - Reward mÃ©dio: -10.11
# EpisÃ³dio 8600/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 8700/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 8800/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 8900/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 9000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 9100/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 9200/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 9300/50000 - Reward mÃ©dio: -10.11
# EpisÃ³dio 9400/50000 - Reward mÃ©dio: -10.16
# EpisÃ³dio 9500/50000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 9600/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 9700/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 9800/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 9900/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 10000/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 10100/50000 - Reward mÃ©dio: -10.27
# EpisÃ³dio 10200/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 10300/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 10400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 10500/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 10600/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 10700/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 10800/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 10900/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 11000/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 11100/50000 - Reward mÃ©dio: -10.15
# EpisÃ³dio 11200/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 11300/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 11400/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 11500/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 11600/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 11700/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 11800/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 11900/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 12000/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 12100/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 12200/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 12300/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 12400/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 12500/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 12600/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 12700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 12800/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 12900/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 13000/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 13100/50000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 13200/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 13300/50000 - Reward mÃ©dio: -10.08
# EpisÃ³dio 13400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 13500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 13600/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 13700/50000 - Reward mÃ©dio: -10.51
# EpisÃ³dio 13800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 13900/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 14000/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 14100/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 14200/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 14300/50000 - Reward mÃ©dio: -10.07
# EpisÃ³dio 14400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 14500/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 14600/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 14700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 14800/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 14900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 15000/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 15100/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 15200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 15300/50000 - Reward mÃ©dio: -10.10
# EpisÃ³dio 15400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 15500/50000 - Reward mÃ©dio: -10.08
# EpisÃ³dio 15600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 15700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 15800/50000 - Reward mÃ©dio: -10.10
# EpisÃ³dio 15900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 16000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 16100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 16200/50000 - Reward mÃ©dio: -10.10
# EpisÃ³dio 16300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 16400/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 16500/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 16600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 16700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 16800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 16900/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 17000/50000 - Reward mÃ©dio: -10.11
# EpisÃ³dio 17100/50000 - Reward mÃ©dio: -10.11
# EpisÃ³dio 17200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 17300/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 17400/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 17500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 17600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 17700/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 17800/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 17900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 18000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 18100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 18200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 18300/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 18400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 18500/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 18600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 18700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 18800/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 18900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 19000/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 19100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 19200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 19300/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 19400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 19500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 19600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 19700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 19800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 19900/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 20000/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 20100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 20200/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 20300/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 20400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 20500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 20600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 20700/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 20800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 20900/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 21000/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 21100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 21200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 21300/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 21400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 21500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 21600/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 21700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 21800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 21900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 22000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 22100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 22200/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 22300/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 22400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 22500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 22600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 22700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 22800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 22900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 23000/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 23100/50000 - Reward mÃ©dio: -10.19
# EpisÃ³dio 23200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 23300/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 23400/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 23500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 23600/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 23700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 23800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 23900/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 24000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 24100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 24200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 24300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 24400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 24500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 24600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 24700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 24800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 24900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 25000/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 25100/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 25200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 25300/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 25400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 25500/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 25600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 25700/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 25800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 25900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 26000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 26100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 26200/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 26300/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 26400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 26500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 26600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 26700/50000 - Reward mÃ©dio: -10.12
# EpisÃ³dio 26800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 26900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 27000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 27100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 27200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 27300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 27400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 27500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 27600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 27700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 27800/50000 - Reward mÃ©dio: -10.16
# EpisÃ³dio 27900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 28000/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 28100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 28200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 28300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 28400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 28500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 28600/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 28700/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 28800/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 28900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 29000/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 29100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 29200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 29300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 29400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 29500/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 29600/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 29700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 29800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 29900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 30000/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 30100/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 30200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 30300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 30400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 30500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 30600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 30700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 30800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 30900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 31000/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 31100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 31200/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 31300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 31400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 31500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 31600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 31700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 31800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 31900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 32000/50000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 32100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 32200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 32300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 32400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 32500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 32600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 32700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 32800/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 32900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 33000/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 33100/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 33200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 33300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 33400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 33500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 33600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 33700/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 33800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 33900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 34000/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 34100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 34200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 34300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 34400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 34500/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 34600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 34700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 34800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 34900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 35000/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 35100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 35200/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 35300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 35400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 35500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 35600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 35700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 35800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 35900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 36000/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 36100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 36200/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 36300/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 36400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 36500/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 36600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 36700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 36800/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 36900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 37000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 37100/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 37200/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 37300/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 37400/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 37500/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 37600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 37700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 37800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 37900/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 38000/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 38100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 38200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 38300/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 38400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 38500/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 38600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 38700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 38800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 38900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 39000/50000 - Reward mÃ©dio: -10.04
# EpisÃ³dio 39100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 39200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 39300/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 39400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 39500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 39600/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 39700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 39800/50000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 39900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 40000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 40100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 40200/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 40300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 40400/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 40500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 40600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 40700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 40800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 40900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 41000/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 41100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 41200/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 41300/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 41400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 41500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 41600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 41700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 41800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 41900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 42000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 42100/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 42200/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 42300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 42400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 42500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 42600/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 42700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 42800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 42900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 43000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 43100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 43200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 43300/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 43400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 43500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 43600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 43700/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 43800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 43900/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 44000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 44100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 44200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 44300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 44400/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 44500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 44600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 44700/50000 - Reward mÃ©dio: -10.57
# EpisÃ³dio 44800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 44900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 45000/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 45100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 45200/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 45300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 45400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 45500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 45600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 45700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 45800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 45900/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 46000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 46100/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 46200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 46300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 46400/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 46500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 46600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 46700/50000 - Reward mÃ©dio: -10.05
# EpisÃ³dio 46800/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 46900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 47000/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 47100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 47200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 47300/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 47400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 47500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 47600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 47700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 47800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 47900/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 48000/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 48100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 48200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 48300/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 48400/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 48500/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 48600/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 48700/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 48800/50000 - Reward mÃ©dio: -10.03
# EpisÃ³dio 48900/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 49000/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 49100/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 49200/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 49300/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 49400/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 49500/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 49600/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 49700/50000 - Reward mÃ©dio: -10.00
# EpisÃ³dio 49800/50000 - Reward mÃ©dio: -10.01
# EpisÃ³dio 49900/50000 - Reward mÃ©dio: -10.02
# EpisÃ³dio 50000/50000 - Reward mÃ©dio: -10.00
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -10.00

# %%
### 5.5 Visualização dos Resultados - REINFORCE

#### Curva de Aprendizado


plot_policy_gradient_learning(
    {'REINFORCE': rewards_reinforce},
    title="REINFORCE - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Estocástica Aprendida


# Visualiza política estocástica (probabilidades)
visualize_stochastic_policy(
    theta_reinforce,
    gw,
    title="REINFORCE - Política Estocástica π(a|s,θ)",
    figsize=(15, 15),
    show_probs=True
)

# %%
#### Política Determinística (Ação Mais Provável)


# Visualiza apenas a ação mais provável em cada estado
plot_policy_arrows(
    theta_reinforce,
    gw,
    title="REINFORCE - Política Determinística (argmax)",
    figsize=(12, 12)
)

# %% [markdown]
# ## 6. REINFORCE com Baseline
#
# ### 6.1 Intuição
#
# **REINFORCE com Baseline** é uma melhoria do REINFORCE que **reduz a variância** subtraindo uma baseline $b(s)$ do retorno $G_t$. A baseline mais comum é a **função valor** $V(s)$.
#
# **Vantagens:**
# - ✅ Menor variância → aprendizado mais estável
# - ✅ Convergência mais rápida
# - ✅ Baseline é aprendida simultaneamente
# - 📊 Mesma convergência garantida (baseline não causa viés)
#
# **Intuição da Baseline:**
# - Se $G_t > V(s)$: a ação foi **melhor que o esperado** → aumenta probabilidade
# - Se $G_t < V(s)$: a ação foi **pior que o esperado** → diminui probabilidade
#
# ### 6.2 Pseudocódigo
#
# ```
# Inicializar θ (política) e w (baseline) arbitrariamente
#
# Para cada episódio:
#     Gerar episódio S₀, A₀, R₁, ..., Sₜ, Aₜ, Rₜ₊₁ seguindo π(·|·,θ)
#
#     Para cada passo t do episódio:
#         Gₜ ← Σₖ₌₀^∞ γᵏ Rₜ₊ₖ₊₁
#
#         δₜ ← Gₜ - V(Sₜ, w)    # Advantage (vantagem)
#
#         # Atualiza baseline
#         w ← w + αw δₜ ∇V(Sₜ, w)
#
#         # Atualiza política
#         θ ← θ + αθ γᵗ δₜ ∇log π(Aₜ|Sₜ,θ)
# ```
#
# ### 6.3 Equações de Atualização
#
# **Advantage (vantagem):**
#
# $$\delta_t = G_t - V(S_t, w)$$
#
# **Atualização da baseline:**
#
# $$w \leftarrow w + \alpha_w \delta_t \nabla V(S_t, w)$$
#
# No nosso caso, $V(S_t, w) = w_{s_t}$ (one-hot encoding), então $\nabla V(S_t, w) = \mathbf{e}_{s_t}$.
#
# **Atualização da política:**
#
# $$\theta \leftarrow \theta + \alpha_\theta \gamma^t \delta_t \nabla \log \pi(A_t|S_t, \theta)$$

# %%
### 6.4 Treinamento do REINFORCE com Baseline

print("="*80)
print("TREINANDO REINFORCE COM BASELINE")
print("="*80)

# Hiperparâmetros
ALPHA_THETA_RB = 2**-9  # Taxa para política (~0.002)
ALPHA_W = 2**-6         # Taxa para baseline (~0.016)

# Treina REINFORCE com Baseline
theta_rb, w_rb, rewards_rb = reinforce_baseline(
    gw,
    n_episodes=N_EPISODES_PG,
    alpha_theta=ALPHA_THETA_RB,
    alpha_w=ALPHA_W,
    gamma=GAMMA_PG,
    initial_state=INITIAL_STATE,
    verbose=False
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_rb[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO REINFORCE COM BASELINE
# ================================================================================
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -10.00

# %%
### 6.5 Visualização dos Resultados - REINFORCE Baseline

#### Curva de Aprendizado


plot_policy_gradient_learning(
    {'REINFORCE + Baseline': rewards_rb},
    title="REINFORCE com Baseline - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Estocástica Aprendida


# Visualiza política estocástica
visualize_stochastic_policy(
    theta_rb,
    gw,
    title="REINFORCE + Baseline - Política Estocástica π(a|s,θ)",
    figsize=(15, 15),
    show_probs=True
)

# %%
#### Política Determinística


# Visualiza ação mais provável
plot_policy_arrows(
    theta_rb,
    gw,
    title="REINFORCE + Baseline - Política Determinística (argmax)",
    figsize=(12, 12)
)

# %% [markdown]
# ## 7. Actor-Critic (One-Step)
#
# ### 7.1 Intuição
#
# **Actor-Critic** combina o melhor de dois mundos:
# - **Actor (Ator)**: Aprende a política $\pi(a|s, \theta)$ (como REINFORCE)
# - **Critic (Crítico)**: Aprende a função valor $V(s, w)$ (como TD)
#
# **Vantagens sobre REINFORCE:**
# - ✅ Atualização **online** (a cada passo, não no fim do episódio)
# - ✅ **Bootstrapping**: usa $V(s')$ ao invés de $G_t$ → menor variância
# - ✅ Mais eficiente em termos de dados
# - 📊 Baseline aprendida pelo critic automaticamente
#
# **Componentes:**
# 1. **Actor**: Política $\pi(a|s, \theta)$ que escolhe ações
# 2. **Critic**: Função valor $V(s, w)$ que avalia estados
# 3. **TD Error**: $\delta = R + \gamma V(s') - V(s)$ guia ambos
#
# ### 7.2 Pseudocódigo
#
# ```
# Inicializar θ (actor) e w (critic) arbitrariamente
#
# Para cada episódio:
#     S ← estado inicial
#     I ← 1  # Fator de desconto acumulado
#
#     Enquanto S não é terminal:
#         A ~ π(·|S,θ)              # Actor escolhe ação
#         Executar A, observar R, S'
#
#         # Calcula TD error
#         δ ← R + γ V(S',w) - V(S,w)
#
#         # Atualiza Critic
#         w ← w + αw δ ∇V(S,w)
#
#         # Atualiza Actor
#         θ ← θ + αθ I δ ∇log π(A|S,θ)
#
#         I ← γI
#         S ← S'
# ```
#
# ### 7.3 Equações de Atualização
#
# **TD Error (sinal de ensino):**
#
# $$\delta_t = R_{t+1} + \gamma V(S_{t+1}, w) - V(S_t, w)$$
#
# **Atualização do Critic:**
#
# $$w \leftarrow w + \alpha_w \delta_t \nabla V(S_t, w)$$
#
# **Atualização do Actor:**
#
# $$\theta \leftarrow \theta + \alpha_\theta I_t \delta_t \nabla \log \pi(A_t|S_t, \theta)$$
#
# onde $I_t = \gamma^t$ é o fator de desconto acumulado.

# %%
### 7.4 Treinamento do Actor-Critic

print("="*80)
print("TREINANDO ACTOR-CRITIC")
print("="*80)

# Hiperparâmetros
ALPHA_THETA_AC = 0.05  # Taxa para actor
ALPHA_W_AC = 0.015     # Taxa para critic

# Treina Actor-Critic
theta_ac, w_ac, rewards_ac = actor_critic(
    gw,
    n_episodes=N_EPISODES_PG,
    alpha_theta=ALPHA_THETA_AC,
    alpha_w=ALPHA_W_AC,
    gamma=GAMMA_PG,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_ac[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO ACTOR-CRITIC
# ================================================================================
# EpisÃ³dio 100/50000 - Reward mÃ©dio: -59.54
# EpisÃ³dio 200/50000 - Reward mÃ©dio: -11.60
# EpisÃ³dio 300/50000 - Reward mÃ©dio: -9.82
# EpisÃ³dio 400/50000 - Reward mÃ©dio: -31.66
# EpisÃ³dio 500/50000 - Reward mÃ©dio: -10.75
# EpisÃ³dio 600/50000 - Reward mÃ©dio: -3.45
# EpisÃ³dio 700/50000 - Reward mÃ©dio: -1.44
# EpisÃ³dio 800/50000 - Reward mÃ©dio: -0.23
# EpisÃ³dio 900/50000 - Reward mÃ©dio: -0.51
# EpisÃ³dio 1000/50000 - Reward mÃ©dio: -0.33
# EpisÃ³dio 1100/50000 - Reward mÃ©dio: -0.13
# EpisÃ³dio 1200/50000 - Reward mÃ©dio: -0.12
# EpisÃ³dio 1300/50000 - Reward mÃ©dio: -0.25
# EpisÃ³dio 1400/50000 - Reward mÃ©dio: -0.23
# EpisÃ³dio 1500/50000 - Reward mÃ©dio: -0.24
# EpisÃ³dio 1600/50000 - Reward mÃ©dio: -0.41
# EpisÃ³dio 1700/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 1800/50000 - Reward mÃ©dio: -0.18
# EpisÃ³dio 1900/50000 - Reward mÃ©dio: -0.09
# EpisÃ³dio 2000/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 2100/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 2200/50000 - Reward mÃ©dio: -0.12
# EpisÃ³dio 2300/50000 - Reward mÃ©dio: -0.08
# EpisÃ³dio 2400/50000 - Reward mÃ©dio: -0.09
# EpisÃ³dio 2500/50000 - Reward mÃ©dio: -0.11
# EpisÃ³dio 2600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 2700/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 2800/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 2900/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 3000/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 3100/50000 - Reward mÃ©dio: -0.05
# EpisÃ³dio 3200/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 3300/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 3400/50000 - Reward mÃ©dio: -0.04
# EpisÃ³dio 3500/50000 - Reward mÃ©dio: -0.04
# EpisÃ³dio 3600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 3700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 3800/50000 - Reward mÃ©dio: -0.08
# EpisÃ³dio 3900/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 4000/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 4100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 4200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 4300/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 4400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 4500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 4600/50000 - Reward mÃ©dio: -0.04
# EpisÃ³dio 4700/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 4800/50000 - Reward mÃ©dio: -0.19
# EpisÃ³dio 4900/50000 - Reward mÃ©dio: -0.04
# EpisÃ³dio 5000/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 5100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 5200/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 5300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 5400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 5500/50000 - Reward mÃ©dio: -0.05
# EpisÃ³dio 5600/50000 - Reward mÃ©dio: -0.06
# EpisÃ³dio 5700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 5800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 5900/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 6000/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 6100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 6200/50000 - Reward mÃ©dio: -0.14
# EpisÃ³dio 6300/50000 - Reward mÃ©dio: -0.16
# EpisÃ³dio 6400/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 6500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 6600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 6700/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 6800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 6900/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 7000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 7100/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 7200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 7300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 7400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 7500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 7600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 7700/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 7800/50000 - Reward mÃ©dio: -0.06
# EpisÃ³dio 7900/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 8000/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 8100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 8200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 8300/50000 - Reward mÃ©dio: -0.04
# EpisÃ³dio 8400/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 8500/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 8600/50000 - Reward mÃ©dio: -0.07
# EpisÃ³dio 8700/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 8800/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 8900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 9000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 9100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 9200/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 9300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 9400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 9500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 9600/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 9700/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 9800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 9900/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 10000/50000 - Reward mÃ©dio: -0.05
# EpisÃ³dio 10100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 10200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 10300/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 10400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 10500/50000 - Reward mÃ©dio: -0.04
# EpisÃ³dio 10600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 10700/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 10800/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 10900/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 11000/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 11100/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 11200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 11300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 11400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 11500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 11600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 11700/50000 - Reward mÃ©dio: -0.11
# EpisÃ³dio 11800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 11900/50000 - Reward mÃ©dio: -0.14
# EpisÃ³dio 12000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 12100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 12200/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 12300/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 12400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 12500/50000 - Reward mÃ©dio: -0.13
# EpisÃ³dio 12600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 12700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 12800/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 12900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 13000/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 13100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 13200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 13300/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 13400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 13500/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 13600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 13700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 13800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 13900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14300/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 14400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 14900/50000 - Reward mÃ©dio: -0.04
# EpisÃ³dio 15000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 15100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 15200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 15300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 15400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 15500/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 15600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 15700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 15800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 15900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 16000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 16100/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 16200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 16300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 16400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 16500/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 16600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 16700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 16800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 16900/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 17000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 17100/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 17200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 17300/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 17400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 17500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 17600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 17700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 17800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 17900/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 18000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 18100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 18200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 18300/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 18400/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 18500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 18600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 18700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 18800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 18900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 19000/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 19100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 19200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 19300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 19400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 19500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 19600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 19700/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 19800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 19900/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 20000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 20100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 20200/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 20300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 20400/50000 - Reward mÃ©dio: -0.16
# EpisÃ³dio 20500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 20600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 20700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 20800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 20900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 21000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 21100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 21200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 21300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 21400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 21500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 21600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 21700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 21800/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 21900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 22000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 22100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 22200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 22300/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 22400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 22500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 22600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 22700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 22800/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 22900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 23000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 23100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 23200/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 23300/50000 - Reward mÃ©dio: -0.20
# EpisÃ³dio 23400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 23500/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 23600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 23700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 23800/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 23900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 24000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 24100/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 24200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 24300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 24400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 24500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 24600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 24700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 24800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 24900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 25000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 25100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 25200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 25300/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 25400/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 25500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 25600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 25700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 25800/50000 - Reward mÃ©dio: -0.08
# EpisÃ³dio 25900/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 26000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 26100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 26200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 26300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 26400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 26500/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 26600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 26700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 26800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 26900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 27800/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 27900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 28000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 28100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 28200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 28300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 28400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 28500/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 28600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 28700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 28800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 28900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29100/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 29200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 29900/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 30000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 30100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 30200/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 30300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 30400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 30500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 30600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 30700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 30800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 30900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 31000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 31100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 31200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 31300/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 31400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 31500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 31600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 31700/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 31800/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 31900/50000 - Reward mÃ©dio: -0.18
# EpisÃ³dio 32000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 32900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 33000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 33100/50000 - Reward mÃ©dio: -0.16
# EpisÃ³dio 33200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 33300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 33400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 33500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 33600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 33700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 33800/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 33900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34400/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 34500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 34900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35400/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 35500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 35900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 36900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 37000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 37100/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 37200/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 37300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 37400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 37500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 37600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 37700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 37800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 37900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 38000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 38100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 38200/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 38300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 38400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 38500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 38600/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 38700/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 38800/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 38900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 39900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40200/50000 - Reward mÃ©dio: -0.08
# EpisÃ³dio 40300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 40900/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 41000/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 41100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 41200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 41300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 41400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 41500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 41600/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 41700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 41800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 41900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 42000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 42100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 42200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 42300/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 42400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 42500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 42600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 42700/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 42800/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 42900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43500/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 43600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 43900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44000/50000 - Reward mÃ©dio: -0.01
# EpisÃ³dio 44100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 44900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 45900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46100/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 46200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 46900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47400/50000 - Reward mÃ©dio: -0.03
# EpisÃ³dio 47500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 47900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48100/50000 - Reward mÃ©dio: -0.02
# EpisÃ³dio 48200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 48900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49000/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49100/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49200/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49300/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49400/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49500/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49600/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49700/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49800/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 49900/50000 - Reward mÃ©dio: 0.00
# EpisÃ³dio 50000/50000 - Reward mÃ©dio: 0.00
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: 0.00

# %%
### 7.5 Visualização dos Resultados - Actor-Critic

#### Curva de Aprendizado


plot_policy_gradient_learning(
    {'Actor-Critic': rewards_ac},
    title="Actor-Critic - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Estocástica Aprendida


# Visualiza política estocástica
visualize_stochastic_policy(
    theta_ac,
    gw,
    title="Actor-Critic - Política Estocástica π(a|s,θ)",
    figsize=(15, 15),
    show_probs=True
)

# %%
#### Política Determinística


# Visualiza ação mais provável
plot_policy_arrows(
    theta_ac,
    gw,
    title="Actor-Critic - Política Determinística (argmax)",
    figsize=(12, 12)
)

# %%
#### Função Valor e Política Juntas


# Visualização especial: Critic (valores) e Actor (política) lado a lado
plot_value_and_policy(
    w_ac,
    theta_ac,
    gw,
    title="Actor-Critic - Função Valor V(s,w) e Política π(a|s,θ)",
    figsize=(20, 10)
)

# %%
## 8. Comparação Final

### 8.1 Comparação das Curvas de Aprendizado

#### Algoritmos Baseados em Valor (TD)


# Compara SARSA, Q-Learning e Expected SARSA
plot_learning_curves(
    {
        'SARSA': rewards_sarsa,
        'Q-Learning': rewards_qlearning,
        'Expected SARSA': rewards_expected
    },
    title="Comparação: Algoritmos TD (Baseados em Valor)",
    figsize=(16, 6)
)

# %%
#### Algoritmos de Gradiente de Política


# Compara REINFORCE, REINFORCE+Baseline e Actor-Critic
plot_policy_gradient_learning(
    {
        'REINFORCE': rewards_reinforce,
        'REINFORCE + Baseline': rewards_rb,
        'Actor-Critic': rewards_ac
    },
    title="Comparação: Algoritmos de Gradiente de Política",
    figsize=(16, 6)
)

# %%
#### Todos os Algoritmos Juntos


# Comparação completa
plot_learning_curves(
    {
        'SARSA': rewards_sarsa,
        'Q-Learning': rewards_qlearning,
        'Expected SARSA': rewards_expected,
        'REINFORCE': rewards_reinforce,
        'REINFORCE + Baseline': rewards_rb,
        'Actor-Critic': rewards_ac
    },
    title="Comparação: Todos os Algoritmos",
    figsize=(18, 6)
)

# %%
### 8.2 Comparação dos Valores Aprendidos (TD)


# Compara valores Q aprendidos pelos algoritmos TD
compare_algorithms(
    {
        'SARSA': Q_sarsa,
        'Q-Learning': Q_qlearning,
        'Expected SARSA': Q_expected
    },
    gw
)
# Out:
# ================================================================================
# COMPARAÇÃO DE VALORES APRENDIDOS
# ================================================================================
#
# Estado         SARSA               Q-Learning          Expected SARSA
# --------------------------------------------------------------------------------
# (0, 0)         -3.9285             -4.1220             -4.5912
# (1, 0)         -5.4031             -4.2022             -4.8257
# (1, 1)         -5.2504             -3.9843             -4.4797
# (1, 2)         -5.0911             -3.5681             -4.1304
# (1, 3)         -5.4881             -3.1083             -3.5249
# (1, 4)         -4.5000             -2.4709             -2.9832
# (1, 5)         -2.1422             -1.5088             -1.9845
# (1, 6)         -1.5486             0.0893              -0.7262
# (1, 7)         -0.4536             2.6875              1.5743
# (1, 8)         1.3807              5.9706              5.1470
# (1, 9)         6.5132              9.4767              9.2821
# (2, 0)         -5.4441             -4.2226             -4.9605
# (2, 1)         -5.3245             -4.2437             -4.8450
# (2, 3)         -5.6309             -3.1481             -3.6949
# (2, 5)         -2.1991             -1.8209             -2.3001
# (2, 7)         -0.5536             -0.5852             -0.5858
# (2, 9)         0.3226              2.2400              0.0000
# (3, 0)         -5.2511             -3.0267             -4.9392
# (3, 2)         -4.3692             -1.3912             -3.4430
# (3, 4)         -1.1948             0.6067              -1.2944
# (3, 6)         -0.2960             3.1140              1.5593
# (3, 8)         4.7282              6.1871              5.3298
# (3, 9)         7.7695              7.9937              7.6933
# (4, 0)         -4.3045             -2.2516             -4.2944
# (4, 1)         -3.6771             -1.3907             -3.4372
# (4, 2)         -2.6663             -0.4341             -2.4285
# (4, 3)         -1.6472             0.6288              -1.2864
# (4, 4)         0.5626              1.8098              0.0540
# (4, 5)         2.1008              3.1220              1.5702
# (4, 6)         4.0581              4.5800              3.3513
# (4, 7)         5.9116              6.2000              5.3649
# (4, 8)         7.9046              8.0000              7.7362
# (4, 9)         10.0000             10.0000             10.0000
# (5, 0)         -5.0397             -3.0264             -4.9350
# ================================================================================
#
# ESTATÍSTICAS RESUMIDAS:
# --------------------------------------------------------------------------------
#
# SARSA:
#   Valor médio:   -0.8868
#   Valor máximo:  10.0000
#   Valor mínimo:  -5.6309
#   Desvio padrão: 4.4886
#
# Q-Learning:
#   Valor médio:   0.7118
#   Valor máximo:  10.0000
#   Valor mínimo:  -4.2437
#   Desvio padrão: 4.2968
#
# Expected SARSA:
#   Valor médio:   -0.3243
#   Valor máximo:  10.0000
#   Valor mínimo:  -4.9605
#   Desvio padrão: 4.4677

# %%
### 8.3 Estatísticas Resumidas


print("\n" + "="*80)
print("ESTATÍSTICAS RESUMIDAS - TODOS OS ALGORITMOS")
print("="*80)

algorithms_results = {
    'SARSA': rewards_sarsa,
    'Q-Learning': rewards_qlearning,
    'Expected SARSA': rewards_expected,
    'REINFORCE': rewards_reinforce,
    'REINFORCE + Baseline': rewards_rb,
    'Actor-Critic': rewards_ac
}

print(f"\n{'Algoritmo':<25} {'Média Final':<15} {'Std Final':<15} {'Melhor':<15}")
print("-"*80)

for name, rewards in algorithms_results.items():
    final_mean = np.mean(rewards[-100:])
    final_std = np.std(rewards[-100:])
    best = np.max(rewards)
    print(f"{name:<25} {final_mean:<15.2f} {final_std:<15.2f} {best:<15.2f}")

print("="*80)
# Out:
# ================================================================================
# ESTATÍSTICAS RESUMIDAS - TODOS OS ALGORITMOS
# ================================================================================
#
# Algoritmo                 Média Final     Std Final       Melhor
# --------------------------------------------------------------------------------
# SARSA                     -4.32           6.55            0.00
# Q-Learning                -4.33           6.28            0.00
# Expected SARSA            -4.46           6.33            0.00
# REINFORCE                 -10.00          0.00            -10.00
# REINFORCE + Baseline      -10.00          0.00            -10.00
# Actor-Critic              0.00            0.00            0.00
# ================================================================================

# %% [markdown]
# ### 8.4 Análise Comparativa
#
#
# ### ANÁLISE COMPARATIVA
#
#
# 🔍 ALGORITMOS TD (Baseados em Valor):
# ---
#
# ✓ SARSA (On-Policy):
#   • Aprende a política que está seguindo (incluindo ε-exploration)
#   • Mais conservador e seguro
#   • Evita caminhos muito próximos ao abismo
#   • Convergência estável
#
# ✓ Q-Learning (Off-Policy):
#   • Aprende a política ótima diretamente
#   • Mais agressivo, pode encontrar caminhos arriscados
#   • Convergência mais rápida
#   • Pode escolher caminhos próximos ao abismo (ótimos mas arriscados)
#
# ✓ Expected SARSA:
#   • Reduz variância usando valor esperado
#   • Compromisso entre SARSA e Q-Learning
#   • Convergência suave e estável
#
#
# 🎭 ALGORITMOS DE GRADIENTE DE POLÍTICA:
# ---
#
# ✓ REINFORCE:
#   • Aprende política estocástica diretamente
#   • Alta variância (usa retornos completos Gt)
#   • Atualizações apenas no fim do episódio
#   • Requer muitos episódios para convergir
#
# ✓ REINFORCE + Baseline:
#   • Reduz variância usando baseline V(s)
#   • Convergência mais rápida que REINFORCE puro
#   • Ainda episódico (atualiza no fim)
#   • Aprende baseline automaticamente
#
# ✓ Actor-Critic:
#   • Atualização ONLINE (a cada passo)
#   • Bootstrapping reduz variância
#   • Mais eficiente em dados
#   • Combina vantagens de TD e Policy Gradient
#
#
# 🏆 COMPARAÇÃO GERAL:
# ---
#
# ### Velocidade de Convergência:
#   1. Q-Learning (mais rápido)
#   2. Expected SARSA
#   3. SARSA
#   4. Actor-Critic
#   5. REINFORCE + Baseline
#   6. REINFORCE (mais lento)
#
# ### Estabilidade:
#   1. Expected SARSA (mais estável)
#   2. Actor-Critic
#   3. SARSA
#   4. REINFORCE + Baseline
#   5. Q-Learning
#   6. REINFORCE (mais instável)
#
# ### Eficiência em Dados:
#   • TD methods > Policy Gradient methods
#   • Actor-Critic > REINFORCE variants
#
# ### Aplicabilidade:
#   • TD methods: Excelentes para espaços discretos
#   • Policy Gradient: Escaláveis para contínuos/alta dimensão

# %%
### 8.5 Visualização Final - Grade Comparativa de Políticas

# Cria visualização comparativa das políticas aprendidas
fig, axes = plt.subplots(2, 3, figsize=(24, 16))

# Políticas TD
for idx, (name, Q, ax) in enumerate([
    ('SARSA', Q_sarsa, axes[0, 0]),
    ('Q-Learning', Q_qlearning, axes[0, 1]),
    ('Expected SARSA', Q_expected, axes[0, 2])
]):
    policy = get_greedy_policy(Q, gw)
    
    ax.set_xlim(-0.5, gw.cols - 0.5)
    ax.set_ylim(gw.rows - 0.5, -0.5)
    ax.set_aspect('equal')
    ax.set_title(f'{name} - Política', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.3)
    
    action_symbols = {'N': '↑', 'S': '↓', 'L': '→', 'O': '←'}
    
    for row in range(gw.rows):
        for col in range(gw.cols):
            state = (row, col)
            
            if state in gw.walls:
                ax.add_patch(plt.Rectangle((col-0.4, row-0.4), 0.8, 0.8, 
                                          facecolor='gray', alpha=0.8))
            elif state in gw.terminal_states:
                reward = gw.terminal_states[state]
                color = 'lightgreen' if reward > 0 else 'lightcoral'
                ax.add_patch(plt.Rectangle((col-0.4, row-0.4), 0.8, 0.8,
                                          facecolor=color, alpha=0.6))
                ax.text(col, row, f'{reward:+.0f}', ha='center', va='center',
                       fontsize=12, fontweight='bold')
            elif state in policy:
                action = policy[state]
                symbol = action_symbols[action]
                ax.text(col, row, symbol, ha='center', va='center',
                       fontsize=20, fontweight='bold', color='blue')
# Políticas PG (mostrar ação mais provável)
from algorithms_extended import compute_softmax_policy

for idx, (name, theta, ax) in enumerate([
    ('REINFORCE', theta_reinforce, axes[1, 0]),
    ('REINFORCE + Baseline', theta_rb, axes[1, 1]),
    ('Actor-Critic', theta_ac, axes[1, 2])
]):
    ax.set_xlim(-0.5, gw.cols - 0.5)
    ax.set_ylim(gw.rows - 0.5, -0.5)
    ax.set_aspect('equal')
    ax.set_title(f'{name} - Política', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.3)
    
    action_symbols = {'N': '↑', 'S': '↓', 'L': '→', 'O': '←'}
    
    for row in range(gw.rows):
        for col in range(gw.cols):
            state = (row, col)
            
            if state in gw.walls:
                ax.add_patch(plt.Rectangle((col-0.4, row-0.4), 0.8, 0.8,
                                          facecolor='gray', alpha=0.8))
            elif state in gw.terminal_states:
                reward = gw.terminal_states[state]
                color = 'lightgreen' if reward > 0 else 'lightcoral'
                ax.add_patch(plt.Rectangle((col-0.4, row-0.4), 0.8, 0.8,
                                          facecolor=color, alpha=0.6))
                ax.text(col, row, f'{reward:+.0f}', ha='center', va='center',
                       fontsize=12, fontweight='bold')
            else:
                probs = compute_softmax_policy(state, theta, gw)
                best_action_idx = np.argmax(probs)
                best_action = gw.actions[best_action_idx]
                symbol = action_symbols[best_action]
                ax.text(col, row, symbol, ha='center', va='center',
                       fontsize=20, fontweight='bold', color='darkgreen')

plt.suptitle('Comparação de Políticas Aprendidas - Todos os Algoritmos',
             fontsize=16, fontweight='bold', y=0.995)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Conclusões
#
# ### Principais Aprendizados:
#
# 1. **Algoritmos TD** convergem mais rápido e são mais eficientes em dados para ambientes discretos
# 2. **Q-Learning** encontra políticas mais agressivas (próximas ao abismo)
# 3. **SARSA** aprende políticas mais conservadoras (caminho seguro)
# 4. **Expected SARSA** oferece o melhor equilíbrio entre velocidade e estabilidade
#
# 5. **REINFORCE** tem alta variância mas funciona bem com ajuste de hiperparâmetros
# 6. **Baseline** reduz significativamente a variância do REINFORCE
# 7. **Actor-Critic** combina vantagens de TD e PG, sendo o mais versátil
#
# ### Quando usar cada algoritmo?
#
# **SARSA**:
# - Quando a exploração tem custo real
# - Ambientes onde segurança é importante
#
# **Q-Learning**:
# - Quando queremos a política ótima rapidamente
# - Podemos tolerar exploração agressiva
#
# **Expected SARSA**:
# - Melhor escolha geral para TD
# - Boa estabilidade e velocidade
#
# **REINFORCE**:
# - Espaços de ação contínuos
# - Quando política estocástica é desejável
#
# **REINFORCE + Baseline**:
# - Versão melhorada do REINFORCE
# - Sempre preferível ao REINFORCE puro
#
# **Actor-Critic**:
# - Alta dimensão / espaços contínuos
# - Atualizações online são importantes
# - Boa opção geral para deep RL
#
# ---
#
# ## 🎓 Referências
#
# - **Sutton & Barto (2018)**: Reinforcement Learning: An Introduction (2nd Ed.)
#   - Capítulo 6: Temporal-Difference Learning
#   - Capítulo 13: Policy Gradient Methods
